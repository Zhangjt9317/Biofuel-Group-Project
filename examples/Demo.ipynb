# %% [markdown]
# ### QSPR MODELING: APPLICATION OF MACHINE LEARNING ALOGRITHMS IN CLASSIFYING THE FAMILY AND PREDICTING FLASH POINTS AND CETANE NUMBER OF BIOFUEL COMPOUNDS

# %% [markdown]
# The aim of this Demo is to make sure all functions in the package work properly.

# %%
import sys
sys.path.append('..')

from MyProject import *  ###import the package
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ec90113fc611> in <module>()
#       2 sys.path.append('..')
#       3
# ----> 4 from MyProject import *  ###import the package
#
# ~/Desktop/Biofuel-Group-Project/MyProject/__init__.py in <module>()
# ----> 1 from .core import *
#
# ~/Desktop/Biofuel-Group-Project/MyProject/core.py in <module>()
#       2 from neupy import algorithms, layers, environment, estimators
#       3 import numpy as np
# ----> 4 import openbabel
#       5 import pandas as pd
#       6 import pubchempy as pcp
#
# ModuleNotFoundError: No module named 'openbabel'

# %% [markdown]
# ### Part 1: Input the CID number for our biofuel component into our software

# %% [markdown]
# * We take [CID = 5700](https://pubchem.ncbi.nlm.nih.gov/compound/5700#section=Top), which is methyl 2-(6-methoxy-6-octadeca-14,16-dienyl-3H-1,2-dioxin-3-yl)acetate, as an example to do the demonstration.
# * ###### We will classify this compound and predict its flash point and cetane number.

# %%
CID = 5700   ###define CID
X = descriptor_generator(CID)   ###generate functional group counts

# %% [markdown]
# ### Part 2: Predict the family of our  biofuel component and return the accuracy of classification model

# %% [markdown]
# * SVM (Support Vector Machine), which has the highest accuracy, is used to classify the compound according to functional groups counts.

# %%
fam = predict_family_svm(X)[0]   ###predict family
print(fam)

# %%
acc = test_svm()       ###print the accuracy of SVM model
print(acc)

# %%
plot_svm(fam)[0]   ###make parity plot on SVM model

# %% [markdown]
# ### Part 3: Predict the physical property of our biofuel component and return the performance of regression model

# %% [markdown]
# * GRNN (General Regression Neural Network), which has the lowest MSE (Mean Squared Error), is used to predict flash point and cetane number according to family and functional group counts.

# %% [markdown]
# ##### 1) Flash Point:

# %%
prop = 'Flash Point'  ###define property

# %%
fp = GRNN_pred(fam, prop, X)   ###predict flash point
print(fp)
# Out:
# 441.0

# %%
GRNN_test(fam, prop)    ###make parity plot, bootstrap vs. mse, bootstrap vs. r2 on GRNN model

# %% [markdown]
# ##### 2) Cetane Number:

# %%
prop = 'Cetane Number'  ###define property

# %%
cn = GRNN_pred(fam, prop, X)   ###predict cetane number
print(cn)
# Out:
# 59.0000000576

# %%
GRNN_test(fam, prop)    ###make parity plot, bootstrap vs. mse, bootstrap vs. r2 on GRNN model
